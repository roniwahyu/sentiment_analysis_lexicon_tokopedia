# %% [markdown]
# Translate dan Labeling Dataset

# %%
#import library yang dibutuhkan
import pandas as pd
import googletrans
from googletrans import Translator
import numpy as np

# %%
#import dataset
df = pd.read_csv("05_hasil_stemming_indo.csv")
df.head()
# Out:
#                                              content  score  \
# 0                               Jelek nggak bisa cod      1
# 1  MASIH ADA KUPON TAPI MALAH GA BISA DIPAKAII, S...      1
# 2                                             mantap      5
# 3                                             manjut      5
# 4  Woy, masa gak ada fitur delete pada barang rek...      1
#
#                                           text_clean  \
# 0                               jelek nggak bisa cod
# 1  masih ada kupon tapi malah ga bisa dipakaii se...
# 2                                             mantap
# 3                                             manjut
# 4  woy masa gak ada fitur delete pada barang reko...
#
#                                        text_stopword  \
# 0                                    jelek nggak cod
# 1  kupon ga dipakaii dipakai baranganya ngga nyas...
# 2                                             mantap
# 3                                             manjut
# 4  woy gak fitur delete barang rekomendasi sih ud...
#
#                                           text_slang  \
# 0                                   jelek enggak cod
# 1  kupon enggak dipakaii dipakai baranganya engga...
# 2                                             mantap
# 3                                             manjut
# 4  woy enggak fitur delete barang rekomendasi sih...
#
#                                    text_no_stopwords  \
# 0                                          jelek cod
# 1  kupon dipakaii dipakai baranganya nyasar kerum...
# 2                                             mantap
# 3                                             manjut
# 4  woy fitur delete barang rekomendasi sih mencob...
#
#                                          text_tokens  \
# 0                                   ['jelek', 'cod']
# 1  ['kupon', 'dipakaii', 'dipakai', 'baranganya',...
# 2                                         ['mantap']
# 3                                         ['manjut']
# 4  ['woy', 'fitur', 'delete', 'barang', 'rekomend...
#
#                                       text_steamindo
# 0                                          jelek cod
# 1  kupon pakai pakai baranganya nyasar rumah oran...
# 2                                             mantap
# 3                                             manjut
# 4  woy fitur delete barang rekomendasi sih coba d...

# %%
#SORT DATA, AMBIL YANG DIBUTUHIN AJA
df = df[['text_steamindo']]
df.rename(columns = {"text_steamindo" : "Ulasan"}, inplace=True) #rename
df.head()
# Out:
#                                               Ulasan
# 0                                          jelek cod
# 1  kupon pakai pakai baranganya nyasar rumah oran...
# 2                                             mantap
# 3                                             manjut
# 4  woy fitur delete barang rekomendasi sih coba d...

# %% [markdown]
# translate

# %%
# translator = Translator()
# translations = {}
# for column in df.columns:
#   #unique elements of the column
#   unique_elements = df[column].unique()
#   for element in unique_elements:
#     #adding all the translation to dictionary (translations)
#     translations[element] = translator.translate(element).text
# translations

# %%
#mengganti semua kata yang diterjemahkan dari kamus ke original dataframe
# df.replace(translations, inplace = True)

# %%
# df.head(10)

# %%
# len(df)

# %%
# df.to_csv("trans-tokopedia.csv", index = False) #tes simpen dulu

# %% [markdown]
# **Lexicon Based Approch (Labeling)**

# %%
df.head()
# Out:
#                                               Ulasan
# 0  Complete application, comfortable, fast, trust...
# 1  There was a great lot when Angus Fak canceled ...
# 2                       garbage apk loading mulu pay
# 3  The apk is not clear, but the message account ...
# 4                                  Tokopedia is good

# %% [markdown]
# Install Vader Lexicon

# %%
# !pip install VaderSentiment
# Out:
# Collecting VaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from VaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->VaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->VaderSentiment) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->VaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->VaderSentiment) (2024.6.2)
# Installing collected packages: VaderSentiment
# Successfully installed VaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
scores = [analyser.polarity_scores(x) for x in df['Ulasan']]
print(scores)
df['Compound_Score'] = [x['compound'] for x in scores]
# Out:
# [{'neg': 0.0, 'neu': 0.355, 'pos': 0.645, 'compound': 0.8442}, {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'compound': 0.6249}, {'neg': 0.259, 'neu': 0.741, 'pos': 0.0, 'compound': -0.1027}, {'neg': 0.096, 'neu': 0.904, 'pos': 0.0, 'compound': -0.1511}, {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}, {'neg': 0.18, 'neu': 0.7, 'pos': 0.12, 'compound': -0.4215}, {'neg': 0.0, 'neu': 0.233, 'pos': 0.767, 'compound': 0.765}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.4215}, {'neg': 0.199, 'neu': 0.566, 'pos': 0.236, 'compound': 0.1002}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.2023}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.129, 'neu': 0.871, 'pos': 0.0, 'compound': -0.6705}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.1531}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.1531}, {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4019}, {'neg': 0.266, 'neu': 0.405, 'pos': 0.329, 'compound': 0.2732}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.1531}, {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'compound': 0.6764}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6249}, {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9393}, {'neg': 0.109, 'neu': 0.703, 'pos': 0.188, 'compound': 0.0618}, {'neg': 0.512, 'neu': 0.488, 'pos': 0.0, 'compound': -0.2732}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6808}, {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.7003}, {'neg': 0.131, 'neu': 0.797, 'pos': 0.071, 'compound': -0.2027}, {'neg': 0.279, 'neu': 0.588, 'pos': 0.132, 'compound': -0.4588}, {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'compound': -0.6652}, {'neg': 0.14, 'neu': 0.787, 'pos': 0.074, 'compound': -0.1556}, {'neg': 0.138, 'neu': 0.599, 'pos': 0.263, 'compound': 0.4754}, {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.1027}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.0772}, {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.2023}, {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.4019}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215}, {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.3612}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.1531}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.179, 'neu': 0.679, 'pos': 0.142, 'compound': -0.1531}, {'neg': 0.264, 'neu': 0.736, 'pos': 0.0, 'compound': -0.0191}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5574}, {'neg': 0.0, 'neu': 0.566, 'pos': 0.434, 'compound': 0.3182}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.1531}, {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.296}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}, {'neg': 0.0, 'neu': 0.164, 'pos': 0.836, 'compound': 0.6249}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.435, 'neu': 0.565, 'pos': 0.0, 'compound': -0.7717}, {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.1531}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.222, 'neu': 0.658, 'pos': 0.119, 'compound': -0.3616}, {'neg': 0.272, 'neu': 0.495, 'pos': 0.233, 'compound': -0.0803}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.089, 'neu': 0.632, 'pos': 0.279, 'compound': 0.802}, {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.4215}, {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}, {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'compound': 0.6249}, {'neg': 0.0, 'neu': 0.739, 'pos': 0.261, 'compound': 0.7184}, {'neg': 0.0, 'neu': 0.3 ...

# %%
df.head(10)
# Out:
#                                               Ulasan  Compound_Score
# 0  Complete application, comfortable, fast, trust...          0.8442
# 1  There was a great lot when Angus Fak canceled ...          0.6249
# 2                       garbage apk loading mulu pay         -0.1027
# 3  The apk is not clear, but the message account ...         -0.1511
# 4                                  Tokopedia is good          0.4404
# 5  Recommended courier send distance to city near...         -0.4215
# 6                       Thank you, great application          0.7650
# 7                                              keren          0.0000
# 8                      nice additional discount huh?          0.4215
# 9  Actually, I like refunds and don't attract sho...          0.1002

# %%
#compound score lexicon based
df.loc[df['Compound_Score'] < 0, 'Sentiments'] = 'Negatif'

df.loc[df['Compound_Score'] == 0, 'Sentiments'] = 'Netral'

df.loc[df['Compound_Score'] > 0, 'Sentiments'] = 'Positif'
df.head(10)
# Out:
#                                               Ulasan  Compound_Score  \
# 0  Complete application, comfortable, fast, trust...          0.8442
# 1  There was a great lot when Angus Fak canceled ...          0.6249
# 2                       garbage apk loading mulu pay         -0.1027
# 3  The apk is not clear, but the message account ...         -0.1511
# 4                                  Tokopedia is good          0.4404
# 5  Recommended courier send distance to city near...         -0.4215
# 6                       Thank you, great application          0.7650
# 7                                              keren          0.0000
# 8                      nice additional discount huh?          0.4215
# 9  Actually, I like refunds and don't attract sho...          0.1002
#
#   Sentiments
# 0    Positif
# 1    Positif
# 2    Negatif
# 3    Negatif
# 4    Positif
# 5    Negatif
# 6    Positif
# 7     Netral
# 8    Positif
# 9    Positif

# %%
#df = df['text_steamindo', 'Compound_Score', 'Sentiments']
#df[['text_steamindo', 'Compound_Score', 'Sentiments']].head() -> untuk menampilkan head yg dipilih

#kode untuk sort data
df = df[['Ulasan', 'Compound_Score', 'Sentiments']]
#sorted_df = new_df.sort_values(by='text_steamindo', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
#sorted_df.head()
df.head()
# Out:
#                                               Ulasan  Compound_Score  \
# 0  Complete application, comfortable, fast, trust...          0.8442
# 1  There was a great lot when Angus Fak canceled ...          0.6249
# 2                       garbage apk loading mulu pay         -0.1027
# 3  The apk is not clear, but the message account ...         -0.1511
# 4                                  Tokopedia is good          0.4404
#
#   Sentiments
# 0    Positif
# 1    Positif
# 2    Negatif
# 3    Negatif
# 4    Positif

# %%
# Menampilkan jumlah sentimen positif dan negatif
jumlah_sentimen = df['Sentiments'].value_counts()
print("Jumlah Sentimen Positif, Negatif dan Netral:")
print(jumlah_sentimen)
# Out:
# Jumlah Sentimen Positif, Negatif dan Netral:
# Sentiments
# Positif    5308
# Negatif    2567
# Netral     2274
# Name: count, dtype: int64

# %%
#simpan hasil
df.to_csv('labeled-tokopedia.csv', index = False)
